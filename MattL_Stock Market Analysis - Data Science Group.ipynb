# %% [markdown]
# Portland Data Group Applied Project
# =================

# %%
#Let's go ahead and start with some imports
import pandas as pd
from pandas import Series,DataFrame
import numpy as np
import datetime

import seaborn as sns
sns.set_style('whitegrid')#give a nice white grid background for visualizations

# remove warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# For Visualization
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')#give a nice white grid background for visualizations
# %matplotlib inline

# %% [markdown]
# Simple and Specific Questions
#
#     Objective 1: Pick a simple question
#
#
# Group Participants:
#
#     Sonny Nallamilli,
#     Robert Lugg,
#     John Burt,
#     Privasha Chatterjee,
#     Manish Saraf

# %%
stock_data=pd.read_csv('C://Users/pmlef/Documents/python_work/Python_for_Data_Analysis/stocks-us-adjClose.csv',parse_dates=True,dayfirst=True,na_values=".")

# %%
#stock_data.info()
#stock_data.shape
#stock_data.describe()
#stock_data.columns
#stock_data.index

# %%
stock_data.rename(columns={'compiled from Yahoo! Finance data by Matt Borthwick': 'Date'},inplace=True)

# %%
stock_data.head()
# Out:
#          Date        ED        DD       CVX        FL       CAT        IP  \
# 0  1970-01-02  0.307997  0.000480  0.582503  1.857836  1.475225  1.808415
# 1  1970-01-05  0.320831  0.000481  0.585290  1.839623  1.470783  1.873423
# 2  1970-01-06  0.316553  0.000477  0.576929  1.845694  1.435234  1.855694
# 3  1970-01-07  0.312275  0.000475  0.575535  1.809266  1.390800  1.814324
# 4  1970-01-08  0.312275  0.000469  0.586683  1.821408  1.395244  1.832054
#
#    SJW   F  LLY ...   EXTN  VYGR  ACG  MIME  TCRZ  MCX  EDIT  LMHA  UA  BTU
# 0  NaN NaN  NaN ...    NaN   NaN  NaN   NaN   NaN  NaN   NaN   NaN NaN  NaN
# 1  NaN NaN  NaN ...    NaN   NaN  NaN   NaN   NaN  NaN   NaN   NaN NaN  NaN
# 2  NaN NaN  NaN ...    NaN   NaN  NaN   NaN   NaN  NaN   NaN   NaN NaN  NaN
# 3  NaN NaN  NaN ...    NaN   NaN  NaN   NaN   NaN  NaN   NaN   NaN NaN  NaN
# 4  NaN NaN  NaN ...    NaN   NaN  NaN   NaN   NaN  NaN   NaN   NaN NaN  NaN
#
# [5 rows x 711 columns]

# %%
stock_data['ED'].plot(legend=True,figsize=(12,5))
stock_data['DD'].plot(legend=True,figsize=(12,5))
stock_data['CVX'].plot(legend=True,figsize=(12,5))
stock_data['FL'].plot(legend=True,figsize=(12,5))
stock_data['CAT'].plot(legend=True,figsize=(12,5))
stock_data['IP'].plot(legend=True,figsize=(12,5))

# %%
#stock_data.head()

# %%
stock_data['Date'] = pd.to_datetime(stock_data['Date'], format = '%Y-%m-%d',  errors='coerce')

# %%
#allstocks_mean = stock_data.mean(axis=1)
#allstocks_sum = stock_data.sum(axis=1)

# %%
stock_data['year'], stock_data['month'], stock_data['day'], stock_data['day_name'], stock_data['decade'], stock_data['quarter']=  stock_data['Date'].dt.year, stock_data['Date'].dt.month, stock_data['Date'].dt.day, stock_data['Date'].dt.weekday_name, (stock_data['Date'].dt.year // 10) * 10, stock_data['Date'].dt.quarter
stock_data['half_yr']=[2 if x>2 else 1 for x in stock_data['Date'].dt.quarter]
stock_data['avg_all']=stock_data.loc[:,'ED':'BTU'].mean(axis=1)
stock_data['sum_all']=stock_data.loc[:,'ED':'BTU'].sum(axis=1)
stock_data['count_all']=stock_data.loc[:,'ED':'BTU'].count(axis=1)
stock_data['min_all']=stock_data.loc[:,'ED':'BTU'].min(axis=1)
stock_data['max_all']=stock_data.loc[:,'ED':'BTU'].max(axis=1)

#stock_data.head()

# %%
stock_data[100:200]
# Out:
#           Date        ED        DD       CVX        FL       CAT        IP  \
# 100 1970-05-26  0.267979  0.000461  0.457870  1.310851  1.110863  1.371796
# 101 1970-05-27  0.270891  0.000481  0.472269  1.422151  1.199732  1.492660
# 102 1970-05-28  0.269435  0.000500  0.489547  1.471616  1.221949  1.516832
# 103 1970-05-29  0.269435  0.000533  0.501065  1.459249  1.244166  1.534962
# 104 1970-06-01  0.267979  0.000528  0.511144  1.471616  1.315261  1.541005
# 105 1970-06-02  0.267979  0.000526  0.505385  1.471616  1.324149  1.583307
# 106 1970-06-03  0.269435  0.000533  0.514024  1.483982  1.315261  1.595393
# 107 1970-06-04  0.269435  0.000526  0.496746  1.415966  1.319705  1.571220
# 108 1970-06-05  0.269435  0.000519  0.485227  1.422151  1.306375  1.498703
# 109 1970-06-08  0.267979  0.000528  0.482348  1.434516  1.284158  1.565177
# 110 1970-06-09  0.269435  0.000535  0.473708  1.440700  1.266384  1.583307
# 111 1970-06-10  0.272348  0.000531  0.473708  1.453067  1.266384  1.577264
# 112 1970-06-11  0.269435  0.000524  0.472269  1.428333  1.244166  1.559135
# 113 1970-06-12  0.272348  0.000534  0.473708  1.440700  1.226392  1.565177
# 114 1970-06-15  0.275261  0.000533  0.472269  1.459249  1.235279  1.559135
# 115 1970-06-16  0.276717  0.000547  0.482348  1.471616  1.270827  1.613523
# 116 1970-06-17  0.278174  0.000537  0.479468  1.471616  1.275271  1.595393
# 117 1970-06-18  0.278174  0.000549  0.485227  1.496349  1.279714  1.565177
# 118 1970-06-19  0.278174  0.000551  0.482348  1.545815  1.279714  1.565177
# 119 1970-06-22  0.276717  0.000557  0.476588  1.527265  1.288600  1.510789
# 120 1970-06-23  0.272348  0.000542  0.473708  1.521082  1.279714  1.480573
# 121 1970-06-24  0.269435  0.000538  0.465069  1.496349  1.279714  1.450357
# 122 1970-06-25  0.270891  0.000543  0.463629  1.508716  1.266384  1.450357
# 123 1970-06-26  0.270891  0.000537  0.465069  1.471616  1.257497  1.444314
# 124 1970-06-29  0.269435  0.000528  0.463629  1.434516  1.230836  1.426185
# 125 1970-06-30  0.267979  0.000523  0.463629  1.446883  1.230836  1.474530
# 126 1970-07-01  0.270891  0.000535  0.462190  1.446883  1.195288  1.498703
# 127 1970-07-02  0.272348  0.000535  0.459310  1.446883  1.181958  1.534962
# 128 1970-07-06  0.269435  0.000516  0.447791  1.459249  1.128637  1.510789
# 129 1970-07-07  0.270891  0.000510  0.443472  1.446883  1.106419  1.498703
# 188  0.913671  5.482029          6  0.000556  1.741226
# 189  0.913989  5.483932          6  0.000552  1.741226
# 190  0.919910  5.519457          6  0.000545  1.759556
# 191  0.926975  5.561848          6  0.000546  1.741226
# 192  0.937816  5.626897          6  0.000557  1.747337
# 193  0.938061  5.628366          6  0.000558  1.753446
# 194  0.938003  5.628016          6  0.000550  1.771775
# 195  0.936203  5.617219          6  0.000545  1.747337
# 196  0.930599  5.583592          6  0.000539  1.747337
# 197  0.920287  5.521721          6  0.000538  1.741852
# 198  0.902029  5.412174          6  0.000536  1.716879
# 199  0.907267  5.443602          6  0.000545  1.735609
#
# [100 rows x 723 columns]

# %%
#stock_data['Quarter'].value_counts()
#stock_data.head()
#stock_data['year'].unique()
#stock_data['decade'].unique()
#stock_data.set_index(['Date'])

# %%
stock_data.head()
# Out:
#         Date        ED        DD       CVX        FL       CAT        IP  SJW  \
# 0 1970-01-02  0.307997  0.000480  0.582503  1.857836  1.475225  1.808415  NaN
# 1 1970-01-05  0.320831  0.000481  0.585290  1.839623  1.470783  1.873423  NaN
# 2 1970-01-06  0.316553  0.000477  0.576929  1.845694  1.435234  1.855694  NaN
# 3 1970-01-07  0.312275  0.000475  0.575535  1.809266  1.390800  1.814324  NaN
# 4 1970-01-08  0.312275  0.000469  0.586683  1.821408  1.395244  1.832054  NaN
#
#     F  LLY    ...     day   day_name  decade  quarter  half_yr   avg_all  \
# 0 NaN  NaN    ...       2     Friday    1970        1        1  1.005409
# 1 NaN  NaN    ...       5     Monday    1970        1        1  1.015072
# 2 NaN  NaN    ...       6    Tuesday    1970        1        1  1.005097
# 3 NaN  NaN    ...       7  Wednesday    1970        1        1  0.983779
# 4 NaN  NaN    ...       8   Thursday    1970        1        1  0.991356
#
#     sum_all  count_all   min_all   max_all
# 0  6.032456          6  0.000480  1.857836
# 1  6.090431          6  0.000481  1.873423
# 2  6.030581          6  0.000477  1.855694
# 3  5.902675          6  0.000475  1.814324
# 4  5.948133          6  0.000469  1.832054
#
# [5 rows x 723 columns]

# %%
stock_data.tail()
# Out:
#             Date         ED         DD         CVX         FL         CAT  \
# 12027 2017-09-01  83.989998        NaN  108.760002  36.340000  118.279999
# 12028 2017-09-05  84.370003  44.799999  109.440002  36.330002  118.300003
# 12029 2017-09-06  84.050003  44.849998  111.790001  36.700001  116.980003
# 12030 2017-09-07  84.739998  44.099998  111.800003  36.160000  117.769997
# 12031 2017-09-08  85.529999  43.500000  110.779999  35.730000  117.820000
#
#               IP        SJW      F        LLY     ...       day   day_name  \
# 12027  54.910000  55.080002  11.35  80.080002     ...         1     Friday
# 12028  54.790001  55.720001  11.36  79.820000     ...         5    Tuesday
# 12029  54.880001  55.900002  11.50  80.510002     ...         6  Wednesday
# 12030  54.689999  56.360001  11.40  81.540001     ...         7   Thursday
# 12031  54.779999  56.709999  11.36  82.919998     ...         8     Friday
#
#        decade  quarter  half_yr    avg_all       sum_all  count_all  min_all  \
# 12027    2010        3        2  47.238849  33303.388342        705   0.1850
# 12028    2010        3        2  46.843592  33071.575822        706   0.1850
# 12029    2010        3        2  47.021151  33196.932374        706   0.1855
# 12030    2010        3        2  47.029779  33203.024142        706   0.1850
# 12031    2010        3        2  47.149265  33287.380886        706   0.1850
#
#            max_all
# 12027  2708.209961
# 12028  2704.949951
# 12029  2704.000000
# 12030  2712.699951
# 12031  2751.699951
#
# [5 rows x 723 columns]

# %% [markdown]
# Data Aggregation
# ==================

# %% [markdown]
# Decade

# %%
decade_groupby = stock_data['count_all'].groupby(stock_data['decade']).count()
decade_groupby
# Out:
# decade
# 1970    2526
# 1980    2528
# 1990    2528
# 2000    2515
# 2010    1935
# Name: count_all, dtype: int64

# %%
decade_groupby = stock_data['avg_all'].groupby(stock_data['decade']).mean()
decade_groupby
# Out:
# decade
# 1970     1.153397
# 1980     3.869789
# 1990    12.231429
# 2000    26.804857
# 2010    36.955809
# Name: avg_all, dtype: float64

# %%
decade_groupby = stock_data['avg_all'].groupby(stock_data['decade']).std()
decade_groupby
# Out:
# decade
# 1970    0.262065
# 1980    1.466351
# 1990    6.242114
# 2000    6.598660
# 2010    7.254714
# Name: avg_all, dtype: float64

# %%
decade_groupby = stock_data['sum_all'].groupby(stock_data['decade']).sum()
decade_groupby
# Out:
# decade
# 1970    4.105849e+04
# 1980    1.180551e+06
# 1990    8.166265e+06
# 2000    2.892271e+07
# 2010    4.533363e+07
# Name: sum_all, dtype: float64

# %%
decade_groupby = stock_data.groupby(['decade'],as_index=False).mean()
decade_groupby
# Out:
#    decade         ED         DD        CVX         FL        CAT         IP  \
# 0    1970   0.352109   0.000740   1.020324   1.598647   2.352759   2.626871
# 1    1980   2.678862   0.001926   3.127509   7.095895   2.938905   6.042379
# 2    1990  10.413444   0.009797  12.970073  13.803549   8.706384  19.858152
# 3    2000  23.364301   0.025670  37.314016  12.071778  31.714613  21.895021
# 4    2010  52.934095  28.926672  89.806580  39.813036  78.129784  35.531290
#
#          SJW          F        LLY     ...              year     month  \
# 0   0.530164   0.328255   0.987046     ...       1974.498416  6.520190
# 1   1.342773   1.426453   2.642840     ...       1984.498022  6.526503
# 2   3.739048   7.319875  17.578816     ...       1994.496440  6.534019
# 3  15.746605   8.820526  36.952690     ...       2004.505368  6.539563
# 4  28.072260  11.544702  52.088846     ...       2013.358656  6.385013
#
#          day   quarter   half_yr    avg_all       sum_all   count_all  \
# 0  15.733571  2.507126  1.502375   1.153397     16.254350   13.503167
# 1  15.750000  2.508703  1.503560   3.869789    466.990055  111.377373
# 2  15.732595  2.511472  1.504747  12.231429   3230.326502  238.433940
# 3  15.758250  2.513718  1.504573  26.804857  11500.082847  424.601988
# 4  15.688889  2.461499  1.485271  36.955809  23428.232969  623.061499
#
#     min_all      max_all
# 0  0.000740     4.450157
# 1  0.001926    55.839138
# 2  0.009797   498.069258
# 3  0.024323  1575.360332
# 4  0.704015  2477.524548
#
# [5 rows x 721 columns]

# %%
decade_groupby = stock_data.groupby(['decade'],as_index=False).sum()
decade_groupby
# Out:
#    decade             ED            DD            CVX            FL  \
# 0    1970     889.427752      1.869261    2577.338799   4038.181721
# 1    1980    6772.162647      4.869409    7906.341970  17938.423150
# 2    1990   26325.186399     24.767405   32788.343404  34895.372879
# 3    2000   58761.215997     64.559143   93844.750903  30360.522285
# 4    2010  102427.473049  55944.183729  173775.731559  77038.224544
#
#              CAT            IP           SJW             F            LLY  \
# 0    5943.069871   6635.475938   1014.734463    628.279555    1889.205506
# 1    7429.551394  15275.135068   3394.528948   3606.072126    6681.100597
# 2   22009.738866  50201.408491   9452.313043  18504.642772   44439.247957
# 3   79762.251803  55065.977837  39602.711400  22183.621964   92936.015090
# 4  151181.132681  68753.046671  54319.822394  22338.998569  100791.916852
#
#        ...          year  month    day  quarter  half_yr       avg_all  \
# 0      ...       4987583  16470  39743     6333     3795   2913.479581
# 1      ...       5016811  16499  39816     6342     3801   9782.826981
# 2      ...       5042087  16518  39772     6349     3804  30921.051973
# 3      ...       5041331  16447  39632     6322     3784  67414.215170
# 4      ...       3895849  12355  30358     4763     2874  71509.491219
#
#         sum_all  count_all      min_all       max_all
# 0  4.105849e+04      34109     1.869261  1.124110e+04
# 1  1.180551e+06     281562     4.869409  1.411613e+05
# 2  8.166265e+06     602761    24.767405  1.259119e+06
# 3  2.892271e+07    1067874    61.171926  3.962031e+06
# 4  4.533363e+07    1205624  1362.268193  4.794010e+06
#
# [5 rows x 721 columns]

# %% [markdown]
# Day of Week

# %%
dayname_groupby = stock_data['count_all'].groupby(stock_data['day_name']).count()
dayname_groupby
# Out:
# day_name
# Friday       2403
# Monday       2284
# Thursday     2417
# Tuesday      2461
# Wednesday    2467
# Name: count_all, dtype: int64

# %%
dayname_groupby = stock_data['avg_all'].groupby(stock_data['day_name']).mean()
dayname_groupby
# Out:
# day_name
# Friday       15.200417
# Monday       15.032962
# Thursday     15.227783
# Tuesday      15.186721
# Wednesday    15.200285
# Name: avg_all, dtype: float64

# %%
dayname_groupby = stock_data['avg_all'].groupby(stock_data['day_name']).std()
dayname_groupby
# Out:
# day_name
# Friday       14.190825
# Monday       14.131008
# Thursday     14.191043
# Tuesday      14.159567
# Wednesday    14.177512
# Name: avg_all, dtype: float64

# %%
dayname_groupby = stock_data.groupby(['day_name'],as_index=False).mean()
dayname_groupby
# Out:
#     day_name         ED        DD        CVX         FL        CAT         IP  \
# 0     Friday  16.259467  4.622331  25.908137  13.650557  22.199933  16.316085
# 1     Monday  16.039216  4.578967  25.548371  13.563029  21.860978  16.161632
# 2   Thursday  16.279809  4.683253  25.930978  13.686562  22.221530  16.324359
# 3    Tuesday  16.251598  4.683863  25.877873  13.679793  22.162843  16.307207
# 4  Wednesday  16.265470  4.715299  25.910886  13.678186  22.211852  16.304140
#
#         SJW         F        LLY     ...         month        day  \
# 0  9.461371  5.864960  21.594573     ...      6.530171  15.799001
# 1  9.318326  5.853162  21.434803     ...      6.612960  15.741681
# 2  9.479389  5.910027  21.668728     ...      6.409185  15.581299
# 3  9.449413  5.910150  21.647851     ...      6.489232  15.781390
# 4  9.474902  5.907858  21.671039     ...      6.498581  15.769761
#
#         decade   quarter   half_yr    avg_all      sum_all   count_all  \
# 0  1989.026217  2.508115  1.506034  15.200417  6970.099027  265.600499
# 1  1988.883538  2.540718  1.511821  15.032962  6871.392156  263.323993
# 2  1989.052544  2.470004  1.489450  15.227783  6982.315429  265.900290
# 3  1989.036977  2.496140  1.498171  15.186721  6959.690481  265.751321
# 4  1989.027158  2.499392  1.499392  15.200285  6970.714060  265.733685
#
#     min_all     max_all
# 0  0.118675  845.955819
# 1  0.121456  838.504818
# 2  0.123295  849.617860
# 3  0.121528  845.394737
# 4  0.119693  845.376208
#
# [5 rows x 722 columns]

# %%
dayname_groupby = stock_data.groupby(['day_name'],as_index=False).sum()
dayname_groupby
# Out:
#     day_name            ED            DD           CVX            FL  \
# 0     Friday  39071.499378  11102.837964  62257.252291  32802.288613
# 1     Monday  36633.570434  10458.361047  58352.478762  30977.958579
# 2   Thursday  39348.299022  11319.421646  62675.172669  33080.420146
# 3    Tuesday  39995.181723  11526.985797  63685.446673  33665.971715
# 4  Wednesday  40126.915287  11632.642493  63922.156240  33744.085526
#
#             CAT            IP           SJW             F           LLY  \
# 0  53346.438228  39207.552178  21609.772196  13395.569494  49322.004038
# 1  49930.473504  36913.166924  20183.495185  12677.948739  46427.783639
# 2  53709.437865  39455.976191  21745.718105  13557.600985  49708.062086
# 3  54542.756578  40132.035722  22064.380267  13800.200936  50547.732972
# 4  54796.638440  40222.312990  22180.744495  13830.294832  50731.903267
#
#        ...       month    day   decade  quarter  half_yr       avg_all  \
# 0      ...       15692  37965  4779630     6027     3619  36526.602138
# 1      ...       15104  35954  4542610     5803     3453  34335.286006
# 2      ...       15491  37660  4807540     5970     3600  36805.551659
# 3      ...       15970  38838  4895020     6143     3687  37374.520911
# 4      ...       16032  38904  4906930     6166     3699  37499.104209
#
#         sum_all  count_all     min_all       max_all
# 0  1.674915e+07     638238  285.175699  2.032832e+06
# 1  1.569426e+07     601432  277.404660  1.915145e+06
# 2  1.687626e+07     642681  298.003428  2.053526e+06
# 3  1.712780e+07     654014  299.080952  2.080516e+06
# 4  1.719675e+07     655565  295.281455  2.085543e+06
#
# [5 rows x 722 columns]

# %% [markdown]
# Quarter

# %%
quarter_groupby = stock_data['count_all'].groupby(stock_data['quarter']).count()
quarter_groupby
# Out:
# quarter
# 1    2970
# 2    3036
# 3    3037
# 4    2989
# Name: count_all, dtype: int64

# %%
quarter_groupby = stock_data['avg_all'].groupby(stock_data['quarter']).mean()
quarter_groupby
# Out:
# quarter
# 1    15.190585
# 2    15.488359
# 3    15.262576
# 4    14.737345
# Name: avg_all, dtype: float64

# %%
quarter_groupby = stock_data['sum_all'].groupby(stock_data['quarter']).sum()
quarter_groupby
# Out:
# quarter
# 1    2.044990e+07
# 2    2.169745e+07
# 3    2.146719e+07
# 4    2.002968e+07
# Name: sum_all, dtype: float64

# %%
quarter_groupby = stock_data.groupby(['quarter'],as_index=False).sum()
quarter_groupby
# Out:
#    quarter            ED            DD           CVX            FL  \
# 0        1  47245.235200  12608.239875  74550.822360  39952.108607
# 1        2  49837.274832  15653.949588  80484.491164  42675.086842
# 2        3  50469.272445  15211.621963  79972.968981  41900.433831
# 3        4  47623.683367  12566.437521  75884.224130  39743.095299
#
#             CAT            IP           SJW             F           LLY  \
# 0  64245.670319  47862.559257  26456.054099  16413.596132  59682.097888
# 1  69933.844650  50178.597474  27180.843437  17583.362114  62971.795079
# 2  68977.645267  50407.002460  27455.068133  17061.467682  63359.830493
# 3  63168.584379  47482.884814  26692.144579  16203.189058  60723.762542
#
#        ...          year  month    day   decade  half_yr       avg_all  \
# 0      ...       5920429   5993  46509  5907570     2970  45116.038811
# 1      ...       6052218  15217  47158  6039060     3036  47022.657738
# 2      ...       6053908  24244  49185  6040780     6074  46352.443840
# 3      ...       5957106  32835  46469  5944320     5978  44049.924535
#
#         sum_all  count_all     min_all       max_all
# 0  2.044990e+07     776337  344.760663  2.545564e+06
# 1  2.169745e+07     810409  409.567361  2.647702e+06
# 2  2.146719e+07     814545  374.267893  2.579539e+06
# 3  2.002968e+07     790639  326.350277  2.394758e+06
#
# [4 rows x 721 columns]

# %%
quarter_groupby = stock_data.groupby(['quarter'],as_index=False).mean()
quarter_groupby
# Out:
#    quarter         ED        DD        CVX         FL        CAT         IP  \
# 0        1  15.907487  4.245199  25.101287  13.451888  21.631539  16.115340
# 1        2  16.415440  5.156110  26.510043  14.056353  23.034863  16.527865
# 2        3  16.618134  5.010416  26.332884  13.796653  22.712428  16.597630
# 3        4  15.932982  4.204228  25.387830  13.296452  21.133685  15.885876
#
#         SJW         F        LLY     ...             year      month  \
# 0  9.502893  5.895688  21.437535     ...      1993.410438   2.017845
# 1  9.483895  6.135158  21.972015     ...      1993.484190   5.012187
# 2  9.437975  5.865063  21.780622     ...      1993.384261   7.982878
# 3  9.329656  5.663470  21.224664     ...      1993.009702  10.985279
#
#          day       decade  half_yr    avg_all      sum_all   count_all  \
# 0  15.659596  1989.080808      1.0  15.190585  6885.486910  261.392929
# 1  15.532938  1989.150198      1.0  15.488359  7146.721172  266.933136
# 2  16.195258  1989.061574      2.0  15.262576  7068.550715  268.207112
# 3  15.546671  1988.732017      2.0  14.737345  6701.132076  264.516226
#
#     min_all     max_all
# 0  0.116081  857.092382
# 1  0.134904  872.102213
# 2  0.123236  849.370597
# 3  0.109184  801.190218
#
# [4 rows x 721 columns]

# %% [markdown]
# Half Year (6 mo)

# %%
half_yr_groupby = stock_data['count_all'].groupby(stock_data['half_yr']).count()
half_yr_groupby
# Out:
# half_yr
# 1    6006
# 2    6026
# Name: count_all, dtype: int64

# %%
half_yr_groupby = stock_data['sum_all'].groupby(stock_data['half_yr']).sum()
half_yr_groupby
# Out:
# half_yr
# 1    4.214734e+07
# 2    4.149687e+07
# Name: sum_all, dtype: float64

# %%
half_yr_groupby = stock_data['avg_all'].groupby(stock_data['half_yr']).mean()
half_yr_groupby
# Out:
# half_yr
# 1    15.341108
# 2    15.002053
# Name: avg_all, dtype: float64

# %%
half_yr_groupby = stock_data.groupby(['half_yr'],as_index=False).sum()
half_yr_groupby
# Out:
#    half_yr            ED            DD            CVX            FL  \
# 0        1  97082.510032  28262.189463  155035.313524  82627.195449
# 1        2  98092.955812  27778.059484  155857.193111  81643.529130
#
#              CAT            IP           SJW             F            LLY  \
# 0  134179.514969  98041.156731  53636.897536  33996.958246  122653.892967
# 1  132146.229646  97889.887274  54147.212712  33264.656740  124083.593035
#
#        ...           year  month    day    decade  quarter       avg_all  \
# 0      ...       11972647  21210  93667  11946630     9042  92138.696549
# 1      ...       12011014  57079  95654  11985100    21067  90402.368374
#
#         sum_all  count_all     min_all       max_all
# 0  4.214734e+07    1586746  754.328024  5.193267e+06
# 1  4.149687e+07    1605184  700.618170  4.974296e+06
#
# [2 rows x 721 columns]

# %%
half_yr_groupby = stock_data.groupby(['half_yr'],as_index=False).mean()
half_yr_groupby
# Out:
#    half_yr         ED        DD        CVX         FL        CAT         IP  \
# 0        1  16.164254  4.705659  25.813406  13.757442  22.340912  16.323869
# 1        2  16.278287  4.610466  25.864121  13.548544  21.929344  16.244588
#
#         SJW         F        LLY     ...             year     month  \
# 0  9.493256  6.017161  21.708654     ...      1993.447719  3.531469
# 1  9.384266  5.765105  21.504955     ...      1993.198473  9.472121
#
#          day       decade   quarter    avg_all      sum_all   count_all  \
# 0  15.595571  1989.115884  1.505495  15.341108  7017.539394  264.193473
# 1  15.873548  1988.898108  3.496017  15.002053  6886.304729  266.376369
#
#     min_all     max_all
# 0  0.125596  864.679769
# 1  0.116266  825.472297
#
# [2 rows x 721 columns]

# %% [markdown]
# Years

# %%
years_groupby = stock_data['count_all'].groupby(stock_data['year']).count()
years_groupby.head(),years_groupby.tail()
# Out:
# (year
#  1970    254
#  1971    253
#  1972    251
#  1973    252
#  1974    253
#  Name: count_all, dtype: int64, year
#  2013    252
#  2014    252
#  2015    252
#  2016    252
#  2017    173
#  Name: count_all, dtype: int64)

# %%
years_groupby = stock_data['sum_all'].groupby(stock_data['year']).sum()
years_groupby.head(),years_groupby.tail()
# Out:
# (year
#  1970    1379.952001
#  1971    1763.375802
#  1972    2389.499695
#  1973    3100.096301
#  1974    2769.259275
#  Name: sum_all, dtype: float64, year
#  2013    6.319880e+06
#  2014    7.517666e+06
#  2015    7.172572e+06
#  2016    6.883239e+06
#  2017    5.480170e+06
#  Name: sum_all, dtype: float64)

# %%
years_groupby = stock_data['avg_all'].groupby(stock_data['year']).mean()
years_groupby.head(),years_groupby.tail()
# Out:
# (year
#  1970    0.905480
#  1971    1.161644
#  1972    1.146690
#  1973    0.988732
#  1974    0.759986
#  Name: avg_all, dtype: float64, year
#  2013    40.881393
#  2014    45.712072
#  2015    41.401916
#  2016    38.747579
#  2017    44.783624
#  Name: avg_all, dtype: float64)

# %%
years_groupby = stock_data.groupby(['year'],as_index=False).sum()
years_groupby.head()
# Out:
#    year         ED        DD         CVX          FL         CAT          IP  \
# 0  1970  73.756515  0.132184  133.878837  416.772719  333.481009  421.930737
# 1  1971  82.246718  0.173462  172.500161  625.196432  436.219098  447.039931
# 2  1972  84.494968  0.208493  206.626735  501.109116  521.221200  489.155099
# 3  1973  82.444191  0.219412  246.943885  311.706354  574.240476  570.456033
# 4  1974  43.438449  0.188930  187.937268  209.935105  497.750894  644.647891
#
#           SJW          F         LLY     ...      month   day  decade  \
# 0         NaN        NaN         NaN     ...       1662  3982  500380
# 1         NaN        NaN         NaN     ...       1660  3961  498410
# 2   74.637154  49.386021  167.757435     ...       1621  3942  494470
# 3  140.694222  75.771676  325.586422     ...       1644  3970  496440
# 4  122.356975  59.989667  281.065280     ...       1649  3982  498410
#
#    quarter  half_yr     avg_all      sum_all  count_all   min_all     max_all
# 0      639      382  229.992000  1379.952001       1524  0.132184  429.232403
# 1      636      381  293.895967  1763.375802       1518  0.173462  625.196432
# 2      624      375  287.819309  2389.499695       2090  0.208493  558.823614
# 3      633      379  249.160483  3100.096301       3192  0.219412  601.367390
# 4      636      381  192.276475  2769.259275       3652  0.188930  644.647891
#
# [5 rows x 721 columns]

# %%
years_groupby = stock_data.groupby(['year'],as_index=False).mean()
years_groupby.head()
# Out:
#    year        ED        DD       CVX        FL       CAT        IP       SJW  \
# 0  1970  0.290380  0.000520  0.527082  1.640837  1.312917  1.661145       NaN
# 1  1971  0.325086  0.000686  0.681819  2.471132  1.724186  1.766956       NaN
# 2  1972  0.336633  0.000831  0.823214  1.996451  2.076578  1.948825  0.511213
# 3  1973  0.327159  0.000871  0.979936  1.236930  2.278732  2.263714  0.558310
# 4  1974  0.171693  0.000747  0.742835  0.829783  1.967395  2.548015  0.483624
#
#           F       LLY    ...        month        day  decade   quarter  \
# 0       NaN       NaN    ...     6.543307  15.677165  1970.0  2.515748
# 1       NaN       NaN    ...     6.561265  15.656126  1970.0  2.513834
# 2  0.338260  1.149024    ...     6.458167  15.705179  1970.0  2.486056
# 3  0.300681  1.292010    ...     6.523810  15.753968  1970.0  2.511905
# 4  0.237113  1.110930    ...     6.517787  15.739130  1970.0  2.513834
#
#     half_yr   avg_all    sum_all  count_all   min_all   max_all
# 0  1.503937  0.905480   5.432882   6.000000  0.000520  1.689891
# 1  1.505929  1.161644   6.969865   6.000000  0.000686  2.471132
# 2  1.494024  1.146690   9.519919   8.326693  0.000831  2.226389
# 3  1.503968  0.988732  12.301969  12.666667  0.000871  2.386379
# 4  1.505929  0.759986  10.945689  14.434783  0.000747  2.548015
#
# [5 rows x 721 columns]

# %% [markdown]
# Year by Quarter

# %%
Year_Quarter = stock_data['count_all'].groupby([stock_data['year'],stock_data['quarter']]).count()
Year_Quarter[:20]
# Out:
# year  quarter
# 1970  1          61
#       2          65
#       3          64
#       4          64
# 1971  1          62
#       2          63
#       3          64
#       4          64
# 1972  1          63
#       2          64
#       3          63
#       4          61
# 1973  1          62
#       2          63
#       3          63
#       4          64
# 1974  1          62
#       2          63
#       3          64
#       4          64
# Name: count_all, dtype: int64

# %%
Year_Quarter = stock_data['sum_all'].groupby([stock_data['year'],stock_data['quarter']]).sum()
Year_Quarter[:20]
# Out:
# year  quarter
# 1970  1          344.662873
#       2          338.682359
#       3          336.259332
#       4          360.347437
# 1971  1          416.947527
#       2          463.053436
#       3          451.724650
#       4          431.650189
# 1972  1          435.656070
#       2          534.623153
#       3          704.149110
#       4          715.071362
# 1973  1          721.347561
#       2          771.114743
#       3          798.218396
#       4          809.415601
# 1974  1          722.668397
#       2          698.862209
#       3          687.724639
#       4          660.004030
# Name: sum_all, dtype: float64

# %%
Year_Quarter = stock_data['avg_all'].groupby([stock_data['year'],stock_data['quarter']]).mean()
Year_Quarter[:20]
# Out:
# year  quarter
# 1970  1          0.941702
#       2          0.868416
#       3          0.875675
#       4          0.938405
# 1971  1          1.120827
#       2          1.225009
#       3          1.176366
#       4          1.124089
# 1972  1          1.152529
#       2          1.145124
#       3          1.117697
#       4          1.172248
# 1973  1          1.163464
#       2          0.987218
#       3          0.905010
#       4          0.903366
# 1974  1          0.832567
#       2          0.792361
#       3          0.730286
#       4          0.687504
# Name: avg_all, dtype: float64

# %%
Year_Quarter = stock_data.groupby([stock_data['year'],stock_data['quarter']]).mean()
#Year_Quarter['qtr_pct']=Year_Quarter['avg_all'].pct_change()
Year_Quarter[:20]
# Out:
#                     ED        DD       CVX        FL       CAT        IP  \
# year quarter
# 1970 1        0.310558  0.000445  0.527545  1.711722  1.399833  1.700108
#      2        0.293067  0.000503  0.480413  1.509571  1.338504  1.588439
#      3        0.275255  0.000559  0.514623  1.598846  1.181194  1.683575
#      4        0.283543  0.000571  0.586498  1.748584  1.335812  1.675419
# 1971 1        0.331517  0.000650  0.655595  2.269339  1.651261  1.816597
#      2        0.323802  0.000681  0.715452  2.622540  1.818852  1.868727
#      3        0.321348  0.000710  0.684481  2.519311  1.817580  1.714769
#      4        0.323857  0.000701  0.671453  2.469399  1.608252  1.670873
# 1972 1        0.339942  0.000781  0.741241  2.240442  1.769340  1.823430
#      2        0.330289  0.000826  0.737158  2.020246  1.967477  2.004970
#      3        0.334205  0.000854  0.834575  1.900511  2.247046  1.910601
#      4        0.342381  0.000862  0.986431  1.818580  2.332302  2.058902
# 1973 1        0.344560  0.000877  1.083844  1.405934  2.307728  2.103953
#      2        0.336426  0.000861  1.056419  1.190706  2.143577  1.978296
#      3        0.320440  0.000852  0.913517  1.198103  2.235761  2.222608
#      4        0.307795  0.000892  0.869369  1.156930  2.425985  2.739906
# 1974 1        0.307482  0.000855  0.830684  1.025033  2.160950  2.796489
#      2        0.160975  0.000892  0.778477  0.959923  2.140403  2.702618
#      3        0.110765  0.000720  0.708287  0.731445  1.839103  2.543115
#      4        0.111628  0.000525  0.657194  0.610866  1.737875  2.160020
#
#                    SJW         F       LLY       AVP    ...     BTU  \
# year quarter                                            ...
# 1970 1             NaN       NaN       NaN       NaN    ...     NaN
#      2             NaN       NaN       NaN       NaN    ...     NaN
#      3             NaN       NaN       NaN       NaN    ...     NaN
#      4             NaN       NaN       NaN       NaN    ...     NaN
# 1971 1             NaN       NaN       NaN       NaN    ...     NaN
#      2             NaN       NaN       NaN       NaN    ...     NaN
#      3             NaN       NaN       NaN       NaN    ...     NaN
#      4             NaN       NaN       NaN       NaN    ...     NaN
# 1972 1             NaN       NaN       NaN       NaN    ...     NaN
#      2        0.504919  0.320020  1.030873  1.904250    ...     NaN
#      3        0.515214  0.323084  1.152700  1.958180    ...     NaN
#      4        0.509351  0.360513  1.187838  2.125322    ...     NaN
# 1973 1        0.532957  0.355037  1.287326  2.212422    ...     NaN
#      2        0.583310  0.304871  1.333100  2.157393    ...     NaN
#      3        0.567388  0.286649  1.290405  1.871011    ...     NaN
#      4        0.549327  0.257713  1.257678  1.363093    ...     NaN
# 1974 1        0.547285  0.247266  1.102437  0.915979    ...     NaN
#      2        0.517506  0.279154  1.214431  0.808172    ...     NaN
#      3        0.436951  0.236428  1.060283  0.487944    ...     NaN
#      4        0.435274  0.186579  1.067920  0.463498    ...     NaN
#
#                   month        day  decade  half_yr   avg_all    sum_all  \
# year quarter
# 1970 1         2.000000  15.459016  1970.0      1.0  0.941702   5.650211
#      2         5.000000  15.461538  1970.0      1.0  0.868416   5.210498
#      3         7.984375  16.312500  1970.0      2.0  0.875675   5.254052
#      4        11.000000  15.468750  1970.0      2.0  0.938405   5.630429
# 1971 1         2.048387  15.241935  1970.0      1.0  1.120827   6.724960
#      2         5.015873  15.730159  1970.0      1.0  1.225009   7.350055
#      3         8.000000  16.218750  1970.0      2.0  1.176366   7.058198
#      4        11.015625  15.421875  1970.0      2.0  1.124089   6.744534
# 1972 1         2.015873  15.428571  1970.0      1.0  1.152529   6.915176
#      2         5.031250  15.531250  1970.0      1.0  1.145124   8.353487
#      3         8.000000  16.380952  1970.0      2.0  1.117697  11.176970
#      4        10.950820  15.475410  1970.0      2.0  1.172248  11.722481
# 1973 1         2.016129  15.516129  1970.0      1.0  1.163464  11.634638
#      2         5.015873  15.412698  1970.0      1.0  0.987218  12.239917
#      3         7.968254  16.349206  1970.0      2.0  0.905010  12.670133
#      4        10.953125  15.734375  1970.0      2.0  0.903366  12.647119
# 1974 1         1.983871  15.838710  1970.0      1.0  0.832567  11.655942
#      2         4.984127  15.492063  1970.0      1.0  0.792361  11.093051
#      3         7.968750  16.046875  1970.0      2.0  0.730286  10.745697
#      4        10.968750  15.578125  1970.0      2.0  0.687504  10.312563
#
#               count_all   min_all   max_all
# year quarter
# 1970 1         6.000000  0.000445  1.729620
#      2         6.000000  0.000503  1.591630
#      3         6.000000  0.000559  1.683576
#      4         6.000000  0.000571  1.758137
# 1971 1         6.000000  0.000650  2.269339
#      2         6.000000  0.000681  2.622540
#      3         6.000000  0.000710  2.519311
#      4         6.000000  0.000701  2.469399
# 1972 1         6.000000  0.000781  2.240442
#      2         7.375000  0.000826  2.091273
#      3        10.000000  0.000854  2.247046
#      4        10.000000  0.000862  2.332302
# 1973 1        10.000000  0.000877  2.311171
#      2        12.603175  0.000861  2.195290
#      3        14.000000  0.000852  2.292343
#      4        14.000000  0.000892  2.739906
# 1974 1        14.000000  0.000855  2.796489
#      2        14.000000  0.000892  2.702618
#      3        14.718750  0.000720  2.543115
#      4        15.000000  0.000525  2.160020
#
# [20 rows x 719 columns]

# %% [markdown]
# Descriptive Statistics Plots
# =============================

# %% [markdown]
# Average Yearly Quarterly Closing

# %%
Year_Quarter_avg = stock_data['avg_all'].groupby([stock_data['year'],stock_data['quarter']]).mean()
Year_Quarter_std = stock_data['avg_all'].groupby([stock_data['year'],stock_data['quarter']]).std()
Year_Quarter_lb=Year_Quarter_avg-1.96*(Year_Quarter_std)
Year_Quarter_ub=Year_Quarter_avg+1.96*(Year_Quarter_std)

# %%
Year_Quarter_avg.plot(legend=True,figsize=(16,7),color='red')
Year_Quarter_lb.plot(figsize=(16,7),color='lightgrey')
Year_Quarter_ub.plot(figsize=(16,7),color='lightgrey')

# %% [markdown]
# Quarterly Percent Change

# %%
Year_Quarter['qtr_pct']=Year_Quarter['avg_all'].pct_change()
Year_qtr_pct=Year_Quarter['qtr_pct']*100
Year_qtr_pct.plot(figsize=(16,7),color='plum')

Year_Quarter_avg.plot(legend=True,figsize=(16,7),color='red')
Year_Quarter_lb.plot(figsize=(16,7),color='lightgrey')
Year_Quarter_ub.plot(figsize=(16,7),color='lightgrey')

# %% [markdown]
# Yearly Closing

# %%
years_groupby_avg = stock_data['avg_all'].groupby(stock_data['year']).mean()
years_groupby_std = stock_data['avg_all'].groupby(stock_data['year']).std()
years_groupby_lb=years_groupby_avg-1.96*(years_groupby_std)
years_groupby_ub=years_groupby_avg+1.96*(years_groupby_std)

# %%
years_groupby_avg.plot(legend=True,figsize=(16,7),color='blue')
years_groupby_lb.plot(figsize=(16,7),color='lightgrey')
years_groupby_ub.plot(figsize=(16,7),color='lightgrey')

# %%
years_groupby_avg = stock_data.groupby(stock_data['year']).mean()
years_groupby_lb=years_groupby_avg['avg_all']-1.96*(years_groupby_std)
years_groupby_ub=years_groupby_avg['avg_all']+1.96*(years_groupby_std)

years_groupby_avg['avg_all'].plot(legend=True,figsize=(16,7),color='blue')
#years_groupby_lb.plot(figsize=(16,7),color='lightgrey')
#years_groupby_ub.plot(figsize=(16,7),color='lightgrey')
years_groupby_avg['ED'].plot(legend=True,figsize=(16,7),color='orange')
years_groupby_avg['DD'].plot(legend=True,figsize=(16,7),color='green')
years_groupby_avg['CVX'].plot(legend=True,figsize=(16,7),color='yellow')
years_groupby_avg['FL'].plot(legend=True,figsize=(16,7),color='pink')
years_groupby_avg['CAT'].plot(legend=True,figsize=(16,7),color='purple')
years_groupby_avg['IP'].plot(legend=True,figsize=(16,7),color='salmon')

# %% [markdown]
# Yearly Percent Change

# %%
years_groupby = stock_data.groupby(stock_data['year']).mean()
years_groupby['yr_pct']=years_groupby['avg_all'].pct_change()
years_pct=years_groupby['yr_pct']*100
years_pct.plot(figsize=(16,7),color='tomato')

years_groupby_avg.plot(legend=True,figsize=(16,7),color='blue')
years_groupby_lb.plot(figsize=(16,7),color='lightgrey')
years_groupby_ub.plot(figsize=(16,7),color='lightgrey')

# %% [markdown]
# Distribution

# %%
stock_data['avg_all'].mean(),stock_data['avg_all'].std()
# Out:
# (15.171298613976987, 14.168217295435538)

# %%
NaN_hist=stock_data['avg_all'].replace(np.NaN,0)
fig = plt.figure(figsize=(16,7))
ax = fig.add_subplot(111)
ax.hist(NaN_hist, 200)
plt.show()

# %%
NaN_hist.max()
# Out:
# 49.205988371775383

# %% [markdown]
# Daily Percent Change

# %%
NaN_hist=stock_data['avg_all'].pct_change().replace(np.NaN,0)
fig = plt.figure(figsize=(16,7))
nbins = 150
xmin = -.25
xmax = .25

ax = fig.add_subplot(111)
ax.hist(NaN_hist, bins=nbins,range=[xmin,xmax])
plt.show()

# %%
import scipy.stats as sp
sp.skew(NaN_hist)
# Out:
# 38.28954411196672

# %%
sp.kurtosis(NaN_hist)
# Out:
# 2905.539377476321

# %% [markdown]
# Rejecting Outliers > 2 Stand. Dev.

# %%
def reject_outliers(data):
    u = np.median(data)
    s = np.std(data)
    filtered = [e for e in data if (u - 2 * s < e < u + 2 * s)]
    return filtered

filtered = reject_outliers(NaN_hist)

plt.hist(filtered, 50)
plt.show()

# %%
sp.skew(filtered)
# Out:
# -0.060866190296143576

# %%
sp.kurtosis(filtered)
# Out:
# 1.6957835195864401

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import mlab

mu = stock_data['avg_all'].mean()
sigma = stock_data['avg_all'].std()
n_bins = 200

x = stock_data['avg_all']

fig, ax = plt.subplots(figsize=(16,7))

# plot the cumulative histogram
n, bins, patches = ax.hist(x, n_bins, normed=1, histtype='step',
                           cumulative=True, label='Empirical')

# Add a line showing the expected distribution.
y = mlab.normpdf(bins, mu, sigma).cumsum()
y /= y[-1]

ax.plot(bins, y, 'k--', linewidth=1.5, label='Theoretical')

# Overlay a reversed cumulative histogram.
ax.hist(x, bins=bins, normed=1, histtype='step', cumulative=-1,
        label='Reversed emp.')

# tidy up the figure
ax.grid(True)
ax.legend(loc='right')
ax.set_title('Cumulative step histograms')
ax.set_xlabel('Average Cumulative Distribution Frequency of Closing Stock')
ax.set_ylabel('Likelihood of occurrence')

plt.show()

# %% [markdown]
# Pareto Distribution

# %%
a, m = 3., 2.  # shape and mode
s = (np.random.pareto(a, 1000) + 1) * m


count, bins, _ = plt.hist(s, 100, normed=True)
fit = a*m**a / bins**(a+1)
plt.plot(bins, max(count)*fit/max(fit), linewidth=2, color='r')
plt.show()

# %%
NaN_hist=stock_data['avg_all'].replace(np.NaN,0)
fig = plt.figure(figsize=(16,7))
ax = fig.add_subplot(111)
ax.hist(NaN_hist, 200)
plt.show()

# %%
NaN_hist.mode()
# Out:
# 0    1.200267
# dtype: float64

# %%
a, m = 1, 1.200267  # shape and mode
s = NaN_hist


count, bins, _ = plt.hist(s, 200, normed=True)
fit = a*m**a / bins**(a+1)
plt.plot(bins, max(count)*fit/max(fit), linewidth=2, color='r')
plt.show()

# 2017 1        43.189678  30535.102272  707.000000  0.865645  1894.286769
#      2        44.951465  31824.920801  707.984127  0.946032  2254.345079
#      3        46.622180  32958.825721  706.937500  0.374062  2636.930201
#
# [87 rows x 720 columns]

# %%
y2k_groupby_avg = stock_data['avg_all'][stock_data['year']>1994].groupby([stock_data['year'],stock_data['quarter']]).mean()
y2k_groupby_avg[:37]
# Out:
# year  quarter
# 1995  1           7.974578
#       2           8.475514
#       3           8.949710
#       4           9.648376
# 1996  1          14.128519
#       2          15.008089
#       3          14.677124
#       4          15.561143
# 1997  1          16.852897
#       2          17.616159
#       3          20.303961
#       4          19.802681
# 1998  1          20.274808
#       2          21.648734
#       3          19.290510
#       4          17.799722
# 1999  1          19.356728
#       2          21.337506
#       3          22.141062
#       4          27.356217
# 2000  1          35.148058
#       2          26.624022
#       3          26.420917
#       4          22.560005
# 2001  1          20.889541
#       2          20.297354
#       3          19.713246
#       4          18.909969
# 2002  1          20.100990
#       2          21.046889
#       3          18.595799
#       4          17.768067
# 2003  1          17.819719
#       2          20.972736
#       3          23.533159
#       4          25.494832
# 2004  1          27.860658
# Name: avg_all, dtype: float64

# %%
y2k_groupby_avg = stock_data['avg_all'][stock_data['year']>1990].groupby(stock_data['year']).mean()
y2k_groupby_std = stock_data['avg_all'][stock_data['year']>1990].groupby(stock_data['year']).std()
y2k_groupby_lb=y2k_groupby_avg-1.96*(y2k_groupby_std)
y2k_groupby_ub=y2k_groupby_avg+1.96*(y2k_groupby_std)

# %%
y2k_groupby_avg.plot(legend=True,figsize=(16,7),color='blue')
y2k_groupby_lb.plot(figsize=(16,7),color='lightgrey')
y2k_groupby_ub.plot(figsize=(16,7),color='lightgrey')

# %% [markdown]
# Min

# %%
y2k_data_min=stock_data[stock_data['year']>1990].copy()
y2k_data_max=stock_data[stock_data['year']>1990].copy()

# %%
y2k_groupby_min=y2k_data_min['min_all'].groupby(y2k_data_min['year']).min()
y2k_groupby_min.plot(figsize=(16,7),color='mistyrose')

# %%
y2k_data_min=y2k_data_min.loc[:,'Date':'BTU'].copy()
y2k_data_min['year']=y2k_data_min['Date'].dt.year
y2k_data_min['min_all']=y2k_data_min.loc[:,'ED':'BTU'].min(axis=1)
y2k_data_min['year']=y2k_data_min['Date'].dt.year
y2k_data_min_gb=y2k_data_min.groupby(y2k_data_min['year']).min()
value_list =y2k_data_min_gb['min_all']
#y2k_data_min_gb

# %%
minimum=y2k_data_min_gb[y2k_data_min_gb.isin(value_list)]
minimum.dropna(axis=1,how='all')
# Out:
#             DD       MUX       SUN       HMY      CETV       BST      CTAA  \
# year
# 1991  0.003621       NaN       NaN       NaN       NaN       NaN       NaN
# 1992  0.005015       NaN       NaN       NaN       NaN       NaN       NaN
# 1993  0.005292       NaN       NaN       NaN       NaN       NaN       NaN
# 1994  0.006035       NaN       NaN       NaN       NaN       NaN       NaN
# 1995  0.006687       NaN       NaN       NaN       NaN       NaN       NaN
# 1996  0.009122       NaN       NaN       NaN       NaN       NaN       NaN
# 1997  0.012756       NaN       NaN       NaN       NaN       NaN       NaN
# 1998  0.014415       NaN       NaN       NaN       NaN       NaN       NaN
# 1999  0.014089       NaN       NaN       NaN       NaN       NaN       NaN
# 2000       NaN       NaN       NaN       NaN  0.005535       NaN       NaN
# 2001       NaN       NaN       NaN       NaN  0.008698       NaN       NaN
# 2002       NaN       NaN       NaN       NaN       NaN  0.008361       NaN
# 2003  0.001237       NaN       NaN       NaN       NaN       NaN       NaN
# 2004  0.001401       NaN       NaN       NaN       NaN       NaN       NaN
# 2005  0.001582       NaN       NaN       NaN       NaN       NaN       NaN
# 2006  0.002327       NaN       NaN       NaN       NaN       NaN       NaN
# 2007  0.003006       NaN       NaN       NaN       NaN       NaN       NaN
# 2008       NaN       NaN       NaN       NaN       NaN       NaN  0.000984
# 2009  0.005800       NaN       NaN       NaN       NaN       NaN       NaN
# 2010       NaN       NaN  0.003489       NaN       NaN       NaN       NaN
# 2011       NaN       NaN  0.027913       NaN       NaN       NaN       NaN
# 2012  0.179238       NaN       NaN       NaN       NaN       NaN       NaN
# 2013  0.409356       NaN       NaN       NaN       NaN       NaN       NaN
# 2014       NaN  0.905998       NaN       NaN       NaN       NaN       NaN
# 2015       NaN       NaN       NaN  0.515508       NaN       NaN       NaN
# 2016       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2017       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#        SB    ELJ   min_all
# year
# 1991  NaN    NaN  0.003621
# 1992  NaN    NaN  0.005015
# 1993  NaN    NaN  0.005292
# 1994  NaN    NaN  0.006035
# 1995  NaN    NaN  0.006687
# 1996  NaN    NaN  0.009122
# 1997  NaN    NaN  0.012756
# 1998  NaN    NaN  0.014415
# 1999  NaN    NaN  0.014089
# 2000  NaN    NaN  0.005535
# 2001  NaN    NaN  0.008698
# 2002  NaN    NaN  0.008361
# 2003  NaN    NaN  0.001237
# 2004  NaN    NaN  0.001401
# 2005  NaN    NaN  0.001582
# 2006  NaN    NaN  0.002327
# 2007  NaN    NaN  0.003006
# 2008  NaN    NaN  0.000984
# 2009  NaN    NaN  0.005800
# 2010  NaN    NaN  0.003489
# 2011  NaN    NaN  0.027913
# 2012  NaN    NaN  0.179238
# 2013  NaN    NaN  0.409356
# 2014  NaN    NaN  0.905998
# 2015  NaN    NaN  0.515508
# 2016  0.3    NaN  0.300000
# 2017  NaN  0.179  0.179000

# %% [markdown]
# Max

# %%
y2k_groupby_max=y2k_data_max['max_all'].groupby(y2k_data_max['year']).max()
y2k_groupby_max.plot(figsize=(16,7),color='lightskyblue')

# %%
y2k_data_max=y2k_data_max.loc[:,'Date':'BTU'].copy()
y2k_data_max['year']=y2k_data_max['Date'].dt.year
y2k_data_max['max_all']=y2k_data_max.loc[:,'ED':'BTU'].max(axis=1)
y2k_data_max['year']=y2k_data_max['Date'].dt.year
y2k_data_max_gb=y2k_data_max.groupby(y2k_data_min['year']).max()
value_list =y2k_data_max_gb['max_all']

# %%
maximum=y2k_data_max_gb[y2k_data_max_gb.isin(value_list)]
maximum.dropna(axis=1,how='all')
# Out:
#              GHC          NVR   AVNW     ARWR         FTAI        EMITF  \
# year
# 1991         NaN          NaN  120.0      NaN          NaN          NaN
# 1992  103.203735          NaN    NaN      NaN          NaN          NaN
# 1993         NaN          NaN    NaN  2925.00          NaN          NaN
# 1994         NaN          NaN    NaN  2193.75          NaN          NaN
# 1995         NaN          NaN    NaN   650.00          NaN          NaN
# 1996         NaN          NaN    NaN      NaN   900.859131          NaN
# 1997         NaN          NaN    NaN      NaN   914.031433          NaN
# 1998         NaN          NaN    NaN      NaN   921.179871          NaN
# 1999         NaN          NaN    NaN      NaN          NaN          NaN
# 2000         NaN          NaN    NaN      NaN          NaN          NaN
# 2001         NaN          NaN    NaN      NaN  1166.153198          NaN
# 2002         NaN          NaN    NaN      NaN          NaN          NaN
# 2003         NaN          NaN    NaN      NaN          NaN          NaN
# 2004         NaN          NaN    NaN      NaN          NaN          NaN
# 2005         NaN          NaN    NaN      NaN          NaN          NaN
# 2006         NaN          NaN    NaN      NaN          NaN  1927.445313
# 2007         NaN          NaN    NaN      NaN          NaN  3445.980469
# 2008         NaN          NaN    NaN      NaN          NaN  3365.399902
# 2009         NaN          NaN    NaN      NaN          NaN  1685.400024
# 2010         NaN          NaN    NaN      NaN          NaN  1485.599976
# 2011         NaN          NaN    NaN      NaN          NaN          NaN
# 2012         NaN          NaN    NaN      NaN          NaN          NaN
# 2013         NaN          NaN    NaN      NaN          NaN          NaN
# 2014         NaN          NaN    NaN      NaN          NaN          NaN
# 2015         NaN          NaN    NaN      NaN          NaN          NaN
# 2016         NaN  1830.000000    NaN      NaN          NaN          NaN
# 2017         NaN  2760.179932    NaN      NaN          NaN          NaN
#
#               FBC    ACTA         BCEI      max_all
# year
# 1991          NaN     NaN          NaN   120.000000
# 1992          NaN     NaN          NaN   103.203735
# 1993          NaN     NaN          NaN  2925.000000
# 1994          NaN     NaN          NaN  2193.750000
# 1995          NaN     NaN          NaN   650.000000
# 1996          NaN     NaN          NaN   900.859131
# 1997          NaN     NaN          NaN   914.031433
# 1998          NaN     NaN          NaN   921.179871
# 1999          NaN  3850.0          NaN  3850.000000
# 2000          NaN  4000.0          NaN  4000.000000
# 2001          NaN     NaN          NaN  1166.153198
# 2002  1053.211914     NaN          NaN  1053.211914
# 2003  2205.729980     NaN          NaN  2205.729980
# 2004  2335.190430     NaN          NaN  2335.190430
# 2005  2010.895020     NaN          NaN  2010.895020
# 2006          NaN     NaN          NaN  1927.445313
# 2007          NaN     NaN          NaN  3445.980469
# 2008          NaN     NaN          NaN  3365.399902
# 2009          NaN     NaN          NaN  1685.400024
# 2010          NaN     NaN          NaN  1485.599976
# 2011          NaN     NaN  1543.262085  1543.262085
# 2012          NaN     NaN  3227.125000  3227.125000
# 2013          NaN     NaN  6298.026855  6298.026855
# 2014          NaN     NaN  6902.833496  6902.833496
# 2015          NaN     NaN  3374.421143  3374.421143
# 2016          NaN     NaN          NaN  1830.000000
# 2017          NaN     NaN          NaN  2760.179932

# %% [markdown]
# Specific Stocks
# ===============
